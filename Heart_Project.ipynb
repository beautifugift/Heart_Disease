# %% [markdown]
# # The Heart

# %% [markdown]
# ![heart.png](attachment:heart.png)

# %% [markdown]
# # Introduction
#
#
#
# The dataset provides a comprehensive array of variables aimed at understanding various aspects related to heart disease and overall health among respondents. It includes information on factors such as whether individuals have reported coronary heart disease or myocardial infarction, their body mass index (BMI), smoking habits, alcohol consumption, history of stroke, physical and mental health status, presence of difficulty in walking or climbing stairs, demographic details such as sex, age category, and race/ethnicity, diabetic status, physical activity levels, general health perception, sleep patterns, and history of conditions like asthma, kidney disease, and skin cancer.
#
# These variables offer insights into the interplay between lifestyle choices, health conditions, and the prevalence of heart disease. By examining factors such as BMI, smoking, alcohol consumption, physical activity, and overall health status, researchers can gain a deeper understanding of the risk factors associated with heart disease and inform interventions aimed at prevention and management.

# %% [markdown]
# # Analysis Objective

# %% [markdown]
# # This analysis is intended to find out the
#
# 1. Understanding the distribution of respondents based on variables such as age category, sex, race/ethnicity, and other          demographic factors.
#
# 2. Examining the prevalence of heart disease, smoking habits, alcohol consumption, and other health-related variables.
#
# 3. Exploring correlations between variables to identify potential risk factors for heart disease.
#
# 4. Visualizing the distribution of BMI, physical and mental health status, physical activity levels, sleep patterns, and other    factors among respondents with and without heart disease.

# %% [markdown]
# # About the dataset
#
#
# Column Descriptions
#
#
# 1. HeartDisease : Respondents that have ever reported having coronary heart disease (CHD) or myocardial infarction (MI).
#
#
# 2. BMI : Body Mass Index (BMI).
#
#
# 3. Smoking : Have you smoked at least 100 cigarettes in your entire life? ( The answer Yes or No ).
#
#
# 4. AlcoholDrinking : Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks         per week
#
#
# 5. Stroke : (Ever told) (you had) a stroke?
#
#
# 6. PhysicalHealth : Now thinking about your physical health, which includes physical illness and injury, for how many days        during the past 30 days was your physical health not good? (0-30 days).
#
#
# 7. MentalHealth : Thinking about your mental health, for how many days during the past 30 days was your mental health not          good? (0-30 days).
#
#
# 8. DiffWalking : Do you have serious difficulty walking or climbing stairs?
#
#
# 9. Sex : Are you male or female?
#
#
# 10. AgeCategory: Fourteen-level age category.
#
#
# 11. Race : Imputed race/ethnicity value.
#
#
# 12. Diabetic : (Ever told) (you had) diabetes?
#
#
# 13. PhysicalActivity : Adults who reported doing physical activity or exercise during the past 30 days other than their 14..       regular job.
#
#
# 14. GenHealth : Would you say that in general your health is...
#
#
# 15. SleepTime : On average, how many hours of sleep do you get in a 24-hour period?
#
#
# 16. Asthma : (Ever told) (you had) asthma?
#
#
# 17. KidneyDisease : Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney               disease?
#
#
# 18. SkinCancer : (Ever told) (you had) skin cancer?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import *

# %% [markdown]
# Reading The Dataset

# %%
df = pd.read_csv("heart_2020_cleaned.csv")
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df.shape
# Out:
# (319795, 18)

# %% [markdown]
# Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
df.isnull()
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              False  False    False            False   False           False
# 1              False  False    False            False   False           False
# 2              False  False    False            False   False           False
# 3              False  False    False            False   False           False
# 4              False  False    False            False   False           False
# ...              ...    ...      ...              ...     ...             ...
# 319790         False  False    False            False   False           False
# 319791         False  False    False            False   False           False
# 319792         False  False    False            False   False           False
# 319793         False  False    False            False   False           False
# 319794         False  False    False            False   False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %% [markdown]
# # Health Condition

# %% [markdown]
# ### What is the prevalence of heart disease in the dataset?

# %%
df["HeartDisease"].value_counts()
# Out:
# No     292422
# Yes     27373
# Name: HeartDisease, dtype: int64

# %%
HeartDisease_rate = df["HeartDisease"].value_counts()
plt.pie(HeartDisease_rate.values, labels= HeartDisease_rate.index,colors=["pink", "lightcoral"], autopct="%1.1f%%")
plt.title("HeartDisease Rate")
plt.show();

# %% [markdown]
# # Insight
#
# Most of the people do not have heart disease

# %% [markdown]
# ### How Many Individuals in the Dataset are Diabetic

# %%
df["Diabetic"].value_counts()
# Out:
# No                         269653
# Yes                         40802
# No, borderline diabetes      6781
# Yes (during pregnancy)       2559
# Name: Diabetic, dtype: int64

# %%
sns.countplot(x = "Sex", hue="Diabetic", data= df)
plt.title("Individuals with Daibetic")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show();

# %% [markdown]
# ### What percentage of individuals have a history of smoke

# %%
df["Smoking"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Create countplot
ax = sns.countplot(x="Sex", hue="Smoking", data=df)

# Add percentages on top of each bar
total = len(df)  # total number of observations

for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.05, f'{height/total:.2%}', ha="center")

# Set plot title, labels, and show the plot
plt.title('Smoking Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # What is the incidence of asthma in the dataset?

# %%
df["Asthma"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Define colors
colors = ["pink", "lightcoral"]


# Create countplot
ax = sns.countplot(x = "Sex", hue="Asthma", data= df, palette=colors)

# Add count values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.05, f'{int(height)}', ha="center")

# Set plot title, labels, and show the plot
plt.title('Individuals with Asthma')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # How many individuals have been diagnosed with kidney disease?

# %%
df["KidneyDisease"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
HeartDisease_rate = df["KidneyDisease"].value_counts()
plt.pie(HeartDisease_rate.values, labels= HeartDisease_rate.index,colors=["pink", "lightcoral"], autopct="%1.1f%%")
plt.title("KidneyDisease Rate")
plt.show();

# %% [markdown]
# # Lifestyle Factors

# %% [markdown]
# # What proportion of individuals engage in smoking and alcohol drinking?

# %%
plt.figure(figsize=(10, 6))

# Create countplot with proportion for Smoking and AlcoholDrinking
sns.countplot(x="Smoking", hue="AlcoholDrinking", data=df, palette="Set2")

plt.title('Proportion of Individuals Engaged in Smoking and Alcohol Drinking')
plt.xlabel('Smoking')
plt.ylabel('Count')
plt.legend(title="Alcohol Drinking", loc="upper right")  # Add legend for Alcohol Drinking
plt.show()

# %%
sns.relplot(
    data=df, kind="line",
    x="Smoking", y="AlcoholDrinking", hue="Sex", style="Sex",
);

# %% [markdown]
# ## How many individuals are physically active based on the provided data?

# %%
sns.countplot(x = "Sex", hue="PhysicalActivity", palette="pastel", data= df)
plt.title("Individuals that are Physically Active")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show();

# %% [markdown]
# ## What is the distribution of BMI in the dataset

# %%
plt.figure(figsize=(8, 6))

# Create a box plot for BMI and Sex
sns.boxplot(x="Sex", y="BMI", data=df)

plt.title('Box Plot of BMI by Sex')
plt.xlabel('Sex')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# ## Is there a correlation between physical activity and mental health?

# %%
x = df["PhysicalHealth"]
y = df["MentalHealth"]

plt.scatter(x, y)
plt.xlabel("PhysicalHealth")
plt.ylabel("MentalHealth")
plt.title("The correlation betwen PhysicalHealth vs MentalHealth")
plt.show()

# %% [markdown]
# There is no correlation between physicalheath vs mentalhealth

# %% [markdown]
# # Physical and Mental Health

# %% [markdown]
# ## What is the avarage physical health Score in the dataset

# %%
average_physical_score = df['PhysicalHealth'].mean()

print(f"Average Physical Score: {average_physical_score:.2f}")
# Out:
# Average Physical Score: 3.37

# %% [markdown]
# ## What is the avarage mental score in the dataset

# %%
avarage_mental_score = df["MentalHealth"].mean()

print(f"Average Mental Score: {avarage_mental_score: 2f}")
# Out:
# Average Mental Score:  3.898366

# %% [markdown]
# ## Is there a relationship beween physical activity and mental health

# %%
x = df['PhysicalActivity']
y = df['MentalHealth']

plt.scatter(x, y)
plt.xlabel("PhysicalActivity")
plt.ylabel("MentalHealth")
plt.title("The correlation betwen MentalHealth vs MentalHealth")
plt.show()

# %% [markdown]
# **There is no relationship between physical activity and mental health**

# %% [markdown]
# # Accessibility and Mobility

# %% [markdown]
# ## How many individuals report difficuty walking in the dataset

# %%
# Define colors
colors = ["pink", "lightcoral"]


# Create countplot
ax = sns.countplot(x = "Sex", hue="DiffWalking", data= df, palette=colors)

# Add count values on top of each bar
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 0.05, f'{int(height)}', ha="center")

# Set plot title, labels, and show the plot
plt.title('Individuals Report with Difficult Walking')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## |what is the percentage rate of the gender in the dataset

# %%
df["Sex"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["Sex"].value_counts()
# Out:
# Female    167805
# Male      151990
# Name: Sex, dtype: int64

# %%
sex_count = df["Sex"].value_counts(normalize = True)
sex_count
# Out:
# Female    0.524727
# Male      0.475273
# Name: Sex, dtype: float64

# %%
plt.pie(sex_count, labels=sex_count.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])

plt.title("Distribution of Sex in the DataFrame")
plt.show()

# %% [markdown]
# Checking the Age Categories

# %%
df["AgeCategory"].unique()
# Out:
# array(['55-59', '80 or older', '65-69', '75-79', '40-44', '70-74',
#        '60-64', '50-54', '45-49', '18-24', '35-39', '30-34', '25-29'],
#       dtype=object)

# %%
#Removing The 'or older' in the dataset

# %%
df['AgeCategory'] = df['AgeCategory'].replace('80 or older', '80-80')

# %%
# Assuming df is your DataFrame
df['AgeCategory'].unique()
# Out:
# array(['55-59', '80-80', '65-69', '75-79', '40-44', '70-74', '60-64',
#        '50-54', '45-49', '18-24', '35-39', '30-34', '25-29'], dtype=object)

# %%
def calculate_average_age(age_range):
    ages = age_range.split('-')
    lower_age = int(ages[0])
    upper_age = int(ages[1]) if len(ages) > 1 else lower_age
    return (lower_age + upper_age) / 2

# %%
df['age_ave'] = df['AgeCategory'].apply(calculate_average_age)

# %%
plt.hist(df['age_ave'], color='skyblue')
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Calculate the count of each category and sort in ascending order
category_counts = df["AgeCategory"].value_counts().sort_index(ascending=True)

# Get the index of categories sorted by count in ascending order
category_order = category_counts.index.tolist()

# Ploting the count plot with categories ordered by count in ascending order
sns.countplot(x="AgeCategory", data=df, order=category_order, palette="viridis")

plt.title("Distribution of Age Categories")
plt.xlabel("Age Category")
plt.ylabel("Count")

plt.show()
